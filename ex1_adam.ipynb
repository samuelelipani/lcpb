# %%
import numpy as np

# %% [markdown]
# # Function plot

# %%
#define function to minimize
b = 20
q = 1/10
w = 10

#function to be minimized
def f(x, y):
    return b*(1-np.exp( - (1/2) * w * (x**2 + y**2))) + (q/2) * ( - x**3 + y)**2

#derivative w.r.t x
def fx(x, y):
    return b * np.exp(-1/2 * w * (x**2 + y**2)) * w * x - 3 * q * x**2 *(-x**3 + y)

#derivative w.r.t y
def fy(x, y):
    return b * np.exp(-1/2 * w * (x**2 + y**2)) * w * y + q *(-x**3 + y)

#gradient
def grad_f(param):
    x = param[0]
    y = param[1]
    return [fx(x,y), fy(x,y)]

# %%
#Make 3D plots
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
#from matplotlib import animation
from IPython.display import HTML
from matplotlib.colors import LogNorm
#from itertools import zip_longest


#Define function for plotting 

def plot_surface(x, y, z, azim=-60, elev=40, dist=10, cmap="RdYlBu_r"):

    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    plot_args = {'rstride': 1, 'cstride': 1, 'cmap':cmap,
             'linewidth': 20, 'antialiased': True,
             'vmin': 0, 'vmax': 65}
    ax.plot_surface(x, y, z, **plot_args)
    ax.view_init(azim=azim, elev=elev)
    ax.dist=dist
    ax.set_xlim(-3, 3)
    ax.set_ylim(-3, 3)
    ax.set_zlim(0, 65)
    
    ax.set_xlabel("x", fontsize=18)
    ax.set_ylabel("y", fontsize=18)
    ax.set_zlabel("z", fontsize=18)
    return fig, ax;

def contour_function():
    #plot function
    x, y = np.meshgrid(np.arange(-3, 3, 0.2), np.arange(-3, 3, 0.2))
    fig, ax = plt.subplots(figsize=(10, 6))
    z=f(x,y)
    cax = ax.contour(x, y, z, levels=np.logspace(0, 5, 35), norm=LogNorm(), cmap="RdYlBu_r")
    ax.plot(0,0, 'r*', markersize=18)

    ax.set_xlabel('$x$')
    ax.set_ylabel('$y$')

    ax.set_xlim((-3, 3))
    ax.set_ylim((-3, 3))
    
    return fig,ax

def overlay_trajectory_contour(ax,trajectory, label,color='k',lw=2):
    xs=trajectory[:,0]
    ys=trajectory[:,1]
    ax.plot(xs,ys, color, label=label,lw=lw)
    return ax;

x, y = np.mgrid[-3:3:31j, -3:3:31j]
fig1,ax1=plot_surface(x,y,f(x,y))
fig4,ax4 =contour_function()
plt.show()

# %% [markdown]
# # Adam

# %%
def adams(grad, init, n_epochs=5000, eta=10**-4, gamma=0.9, beta=0.99,epsilon=10**-8,noise_strength=0):
    params = np.array(init)
    param_traj = np.zeros([n_epochs+1,2])
    param_traj[0,] = init
    v=0;
    grad_sq=0;
    for j in range(n_epochs) :
        noise = noise_strength*np.random.randn(params.size)
        g = np.array(grad(params)) + noise
        v = gamma*v + (1-gamma)*g
        grad_sq = beta*grad_sq + (1-beta)*g*g
        v_hat = v/(1-gamma)
        grad_sq_hat = grad_sq/(1-beta)
        params = params - eta*np.divide(v_hat,np.sqrt(grad_sq_hat+epsilon))
        param_traj[j+1,] = params
    return param_traj

# %%
x, y = np.meshgrid(np.arange(-3, 3, 0.2), np.arange(-3, 3, 0.2))
fig, ax = plt.subplots(figsize=(10, 6))
z = f(x,y)
ax.contour(x, y, z, levels=np.logspace(0.0, 5, 35), norm=LogNorm(), cmap="RdYlBu_r")
ax.plot(0,0, 'r*', markersize=18);
#overlay_trajectory_contour(ax,b,'g--*', lw=0.5)

learning_rates = np.logspace(-5,-2,4)*10
initial_points = [[-1,2], [1,1], [2,2], [-1,-3]]

for eta,init in zip(learning_rates,initial_points):
    gdn = adams(grad_f,init, eta=eta)
    overlay_trajectory_contour(ax,gdn,'$\eta=$%s'% eta,lw=0.5)
    plt.scatter(init[0], init[1])

plt.legend(loc=2)
plt.show()

# %%
x, y = np.meshgrid(np.arange(-3, 3, 1), np.arange(-3, 3, 1))
starting_points = np.array([[i,j] for i,j in zip(np.concatenate(x),np.concatenate(y))])

test = []

gamma_list = np.linspace(0.8,0.99,5)
eta_list = np.logspace(-4,-1,4)
beta_list = np.linspace(0.8,0.99,5)

for gamma in gamma_list :
    for eta in eta_list :
        for beta in beta_list :
            gd_1 = []
            for init1 in starting_points:
                gd_1.append(adams(grad_f, init1, eta = eta, gamma = gamma, beta = beta, n_epochs=100)[-1])
            test.append((np.array(gd_1)**2).sum(axis = 1).mean())

# %%
np.argmin(np.array(test))#.reshape((5,4,5))
# Out:
# 57

# %%
np.array(test).shape
# Out:
# (100,)

# %%
v = np.array(test).reshape((5,4,5)) #gamma, eta, beta
indices = np.array(np.where(v == v.min())).ravel()
print(indices)
# Out:
# [2 3 2]

# %%
x, y = np.meshgrid(np.arange(-3, 3, 1), np.arange(-3, 3, 1))
starting_points = np.array([[i,j] for i,j in zip(np.concatenate(x),np.concatenate(y))])

gamma_best = gamma_list[indices[0]]
eta_best = eta_list[indices[1]]
beta_best = beta_list[indices[2]]
test = []

for init1 in starting_points:
    gd_1 = adams(grad_f,init1, gamma = gamma_best, eta = eta_best, beta = beta_best) #5000 it.
    test.append((np.array(gd_1)**2).sum(axis = 1))

#this time we calculate the parameter t  for each iteration
test_best_adam = np.array(test).mean(axis = 0)

# %%
plt.plot(range(0,101),test_best_adam[:101],label = "ADAM Solver")
plt.xlabel('n_epochs')
plt.ylabel('t')
#plt.xscale('log')
plt.title('ADAM Solver')
plt.legend();
plt.show()

# %%
test_best_adam[5:10]
# Out:
# array([4.30574624, 4.05911754, 3.90344582, 3.81192056, 3.74421386])
